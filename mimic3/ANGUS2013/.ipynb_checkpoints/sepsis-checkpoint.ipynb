# %%
import psycopg2
import sys
import pprint
import pandas
import random

# %%
def connect():
    "return a connection"
    conn_string = "host='localhost' dbname='mimic' user='postgres'"
    conn = psycopg2.connect(conn_string)
    return conn
    
def disconnect(conn):
    "disconnect"
    conn.commit()
    conn.close()

def get_data( query, itersize=10000):
    "return a pandas dataframe with columns names"
    conn = connect()
    cur = conn.cursor(f'tmpCursor')
    cur.itersize = itersize
    cur.execute(query)
    pd = pandas.DataFrame(cur.fetchall(),columns= [desc[0] for desc in cur.description])
    cur.close()
    disconnect(conn)
    return pd

# %%
print(get_data("select itemid from mimiciii.d_items where lower(label) like '%evophed%' or lower(label) like '%pressin%' or lower(label) like '%ephrin%' "))

# %%
 print(get_data("SELECT table_schema, table_name FROM information_schema.tables WHERE table_schema IN (  'mimiciii')"))
# Out:
#    table_schema          table_name
# 0      mimiciii    d_icd_procedures
# 1      mimiciii          admissions
# 2      mimiciii             callout
# 3      mimiciii          caregivers
# 4      mimiciii       chartevents_1
# 5      mimiciii       chartevents_2
# 6      mimiciii       chartevents_3
# 7      mimiciii       chartevents_4
# 8      mimiciii       chartevents_5
# 9      mimiciii       chartevents_6
# 10     mimiciii       chartevents_7
# 11     mimiciii       chartevents_8
# 12     mimiciii       chartevents_9
# 13     mimiciii      chartevents_10
# 14     mimiciii      chartevents_11
# 15     mimiciii      chartevents_12
# 16     mimiciii      chartevents_13
# 17     mimiciii      chartevents_14
# 18     mimiciii         chartevents
# 19     mimiciii           cptevents
# 20     mimiciii      datetimeevents
# 21     mimiciii       diagnoses_icd
# 22     mimiciii            drgcodes
# 23     mimiciii               d_cpt
# 24     mimiciii     d_icd_diagnoses
# 25     mimiciii             d_items
# 26     mimiciii          d_labitems
# 27     mimiciii            icustays
# 28     mimiciii      inputevents_cv
# 29     mimiciii      inputevents_mv
# 30     mimiciii           labevents
# 31     mimiciii  microbiologyevents
# 32     mimiciii          noteevents
# 33     mimiciii        outputevents
# 34     mimiciii            patients
# 35     mimiciii       prescriptions
# 36     mimiciii  procedureevents_mv
# 37     mimiciii      procedures_icd
# 38     mimiciii            services
# 39     mimiciii           transfers

# %%
 print(get_data("SELECT * FROM sepsis.general_vars LIMIT 10"))
# Out:
#    subject_id  hadm_id
# 0           2   163353
# 1           3   145834
# 2           4   185777
# 3           5   178980
# 4           6   107064
# 5           7   118037
# 6           8   159514
# 7           9   150750
# 8          10   184167
# 9          11   194540

# %%
ref = get_data("SELECT * FROM mimiciii.d_items WHERE label ~* 'temp' AND linksto = 'chartevents'")
print(ref)
ref.to_csv('ITEMS_TEMP_20170606.csv')
# Out:
#     row_id  itemid                                              label  \
# 0      548     591                                  RLE [Temperature]
# 1      554     597                                  RUE [Temperature]
# 2      384     417                                  Inspired Gas Temp
# 3      391     424                                         LLE [Temp]
# 4      394     427                                         LUE [Temp]
# 5      598     645                                 Skin [Temperature]
# 6      626     674                                         Temp. Site
# 7      627     676                                      Temperature C
# 8      628     677                               Temperature C (calc)
# 9      629     678                                      Temperature F
# 10     630     679                               Temperature F (calc)
# 11    1053    3460                               Humidity Temp [Meas]
# 12    1740    5632                                R BREAST TEMP/COLOR
# 13    1760    5652                                       PICC Attempt
# 14    1875    5772                                    FLAP TEMP/COLOR
# 15    3708    2668                                         TEMP GRAFT
# 16    3850    2882                                    FLAP COLOR/TEMP
# 17    2816    3652                                  Temp Axillary [F]
# 18    2817    3653                                     Temp CoB 1/W/C
# 19    2818    3654                                    Temp Rectal [F]
# 20    2819    3655                                      Temp Skin [C]
# 21    2820    3656                             Temp/Iso/Warmer [Type]
# 22    4103    6277                                  PICC line attempt
# 23    4912    8449       Patient controlled analgesia (PCA) [Attempt]
# 24    5007    8537           Temp/Iso/Warmer [Temperature, degrees C]
# 25    4298    6643                                        Temp Rectal
# 26   13042  224027                                   Skin Temperature
# 27   14731  227054                              TemperatureF_ApacheIV
# 28   14732  227055                                 TempScore_ApacheIV
# 29   13867  225571  Number of attempts required to place line (A-L...
# ..     ...     ...                                                ...
# 49   13302  224769                                           LUE Temp
# 50   13303  224771                                           RLE Temp
# 51   13304  224773                                           LLE Temp
# 52   14972  227627                         Arctic Sun/Alsius Set Temp
# 53   14973  227628                              Arctic Sun Water Temp
# 54   14975  227630                        Arctic Sun Temp #1 Location
# 55   14976  227631                        Arctic Sun Temp #2 Location
# 56   14977  227632                        Arctic Sun/Alsius Temp #1 C
# 57   14978  227634                        Arctic Sun/Alsius Temp #2 C
# 58   13441  224837              Temporary Ventricular Sens Setting mV
# 59   13442  224838              Temporary Ventricular Stim Setting mA
# 60   13443  224839                   Temporary Pacemaker Wires Atrial
# 61   13462  224866                           Temporary Atrial Capture
# 62   14305  226011                         Number of attempts (PACEN)
# 63   13408  224584   Number of attempts required to place line (PICC)
# 64   13423  224642                                   Temperature Site
# 65   13436  224663                                        PCA attempt
# 66   15236  228242                        Pt. Temperature (BG) (SOFT)
# 67   12737  220194                              Temporary AV interval
# 68   13631  224834                         Temporary Ventricular Sens
# 69   13632  224835                      Temporary Ventricular Capture
# 70   14538  226777                                  TempApacheIIScore
# 71   14539  226778                                  TempApacheIIValue
# 72   12816  223872                                 Inspired Gas Temp.
# 73   14446  226329                          Blood Temperature CCO (C)
# 74   15271  228074                 Number of attempts to perform (LP)
# 75   15285  228090                         Number of attempts (THCEN)
# 76   12757  223761                             Temperature Fahrenheit
# 77   12758  223762                                Temperature Celsius
# 78   13684  225306                    Number of Attempts (Intubation)
#
#                                          abbreviation    dbsource  \
# 0                                                None     carevue
# 1                                                None     carevue
# 2                                                None     carevue
# 3                                                None     carevue
# 4                                                None     carevue
# 5                                                None     carevue
# 6                                                None     carevue
# 7                                                None     carevue
# 8                                                None     carevue
# 9                                                None     carevue
# 10                                               None     carevue
# 11                                               None     carevue
# 12                                               None     carevue
# 13                                               None     carevue
# 14                                               None     carevue
# 15                                               None     carevue
# 16                                               None     carevue
# 17                                               None     carevue
# 18                                               None     carevue
# 19                                               None     carevue
# 20                                               None     carevue
# 21                                               None     carevue
# 22                                               None     carevue
# 23                                               None     carevue
# 24                                               None     carevue
# 25                                               None     carevue
# 26                                          Skin Temp  metavision
# 27                              TemperatureF_ApacheIV  metavision
# 28                                 TempScore_ApacheIV  metavision
# 29  Number of attempts required to place line (A-L...  metavision
# ..                                                ...         ...
# 49                                           LUE Temp  metavision
# 50                                           RLE Temp  metavision
# 51                                           LLE Temp  metavision
# 52                         Arctic Sun/Alsius Set Temp  metavision
# 53                              Arctic Sun Water Temp  metavision
# 54                        Arctic Sun Temp #1 Location  metavision
# 55                        Arctic Sun Temp #2 Location  metavision
# 56                        Arctic Sun/Alsius Temp #1 C  metavision
# 57                        Arctic Sun/Alsius Temp #2 C  metavision
# 58                   Temp Ventricular Sens Setting mV  metavision
# 59                   Temp Ventricular Stim Setting mA  metavision
# 60                        Temp Pacemaker Wires Atrial  metavision
# 61                                Temp Atrial Capture  metavision
# 62                         Number of attempts (PACEN)  metavision
# 63   Number of attempts required to place line (PICC)  metavision
# 64                                          Temp Site  metavision
# 65                                        PCA attempt  metavision
# 66                        Pt. Temperature (BG) (SOFT)  metavision
# 67                                   Temp AV interval  metavision
# 68                              Temp Ventricular Sens  metavision
# 69                           Temp Ventricular Capture  metavision
# 70                                  TempApacheIIScore  metavision
# 71                                  TempApacheIIValue  metavision
# 72                                 Inspired Gas Temp.  metavision
# 73                                 Blood Temp CCO (C)  metavision
# 74                 Number of attempts to perform (LP)  metavision
# 75                         Number of attempts (THCEN)  metavision
# 76                                      Temperature F  metavision
# 77                                      Temperature C  metavision
# 78                    Number of Attempts (Intubation)  metavision
#
#         linksto                     category unitname param_type conceptid
# 0   chartevents                         None     None       None      None
# 1   chartevents                         None     None       None      None
# 2   chartevents                         None     None       None      None
# 3   chartevents                         None     None       None      None
# 4   chartevents                         None     None       None      None
# 5   chartevents                         None     None       None      None
# 6   chartevents                         None     None       None      None
# 7   chartevents                         None     None       None      None
# 8   chartevents                         None     None       None      None
# 9   chartevents                         None     None       None      None
# 10  chartevents                         None     None       None      None
# 11  chartevents                         None     None       None      None
# 12  chartevents                         None     None       None      None
# 13  chartevents                         None     None       None      None
# 14  chartevents                         None     None       None      None
# 15  chartevents                         None     None       None      None
# 16  chartevents                         None     None       None      None
# 17  chartevents                         None     None       None      None
# 18  chartevents                         None     None       None      None
# 19  chartevents                         None     None       None      None
# 20  chartevents                         None     None       None      None
# 21  chartevents                         None     None       None      None
# 22  chartevents                         None     None       None      None
# 23  chartevents                         None     None       None      None
# 24  chartevents                         None     None       None      None
# 25  chartevents                         None     None       None      None
# 26  chartevents            Skin - Assessment     None       Text      None
# 27  chartevents       Scores - APACHE IV (2)       ?F    Numeric      None
# 28  chartevents       Scores - APACHE IV (2)     None    Numeric      None
# 29  chartevents      Arterial Line Insertion     None       Text      None
# ..          ...                          ...      ...        ...       ...
# 49  chartevents               Cardiovascular     None       Text      None
# 50  chartevents               Cardiovascular     None       Text      None
# 51  chartevents               Cardiovascular     None       Text      None
# 52  chartevents                   Treatments       ?C    Numeric      None
# 53  chartevents                   Treatments       ?C    Numeric      None
# 54  chartevents          Routine Vital Signs     None       Text      None
# 55  chartevents          Routine Vital Signs     None       Text      None
# 56  chartevents          Routine Vital Signs       ?C    Numeric      None
# 57  chartevents          Routine Vital Signs       ?C    Numeric      None
# 58  chartevents  Cardiovascular (Pacer Data)       mV    Numeric      None
# 59  chartevents  Cardiovascular (Pacer Data)       mA    Numeric      None
# 60  chartevents  Cardiovascular (Pacer Data)     None    Numeric      None
# 61  chartevents  Cardiovascular (Pacer Data)     None       Text      None
# 62  chartevents                 Paracentesis     None    Numeric      None
# 63  chartevents          PICC Line Insertion     None       Text      None
# 64  chartevents          Routine Vital Signs     None       Text      None
# 65  chartevents                Pain/Sedation     None    Numeric      None
# 66  chartevents                         Labs     None    Numeric      None
# 67  chartevents  Cardiovascular (Pacer Data)     msec    Numeric      None
# 68  chartevents  Cardiovascular (Pacer Data)     None       Text      None
# 69  chartevents  Cardiovascular (Pacer Data)     None       Text      None
# 70  chartevents           Scores - APACHE II     None    Numeric      None
# 71  chartevents           Scores - APACHE II       ?F    Numeric      None
# 72  chartevents                  Respiratory       ?C    Numeric      None
# 73  chartevents          Routine Vital Signs       ?C    Numeric      None
# 74  chartevents              Lumbar Puncture     None       Text      None
# 75  chartevents                Thoracentesis     None    Numeric      None
# 76  chartevents          Routine Vital Signs       ?F    Numeric      None
# 77  chartevents          Routine Vital Signs       ?C    Numeric      None
# 78  chartevents                   Intubation     None       Text      None
#
# [79 rows x 10 columns]

# %%
def inStmt(col):
    "generates list"
    return ','.join(col.map(str))

# %%
cardiac_index = pandas.read_csv("ITEMS_CARDIAC_INDEX_201511111831.csv")
mean_pressure = pandas.read_csv("ITEMS_MEAN_PRESSURE_201511111723.csv")
systol_pressure = pandas.read_csv("ITEMS_SYSTOL_PRESSURE_201511111657-3.csv")
thromb = pandas.read_csv("ITEMS_THROMB_201511111845.csv")
venus_sat = pandas.read_csv("ITEMS_VENUS_SAT_201511111810.csv")
weight = pandas.read_csv("ITEMS_WEIGHT_20170606.csv")
temp = pandas.read_csv("ITEMS_TEMP_20170606.csv")
tmp = temp[temp['conceptid'] == True]
print(inStmt(tmp['itemid']))
a = get_data("SELECT * FROM mimiciii.d_icd_diagnoses")
a.to_csv('diag.csv')
# Out:
# 591,597,424,427,645,674,676,677,678,679,3652,3654,3655,8537,6643,224027,224390,224642,228242,223761

# %%
print(get_data('WITH urine AS (SELECT icustay_id, value, charttime, ROW_NUMBER() OVER(PARTITION BY icustay_id ORDER BY charttime) as position \
FROM mimiciii.outputevents WHERE  itemid = 40055  ),\
              tmp as ( SELECT o1.icustay_id, o1.position, o2.position, o1.charttime, o2.charttime, EXTRACT(epoch FROM (o2.charttime - o1.charttime))/3600 as duree, coalesce(o2.value,o1.value) as val,   \
               coalesce(o2.value,o1.value) / (EXTRACT(epoch FROM (o2.charttime - o1.charttime))/3600) vol_per_hour, \
               CASE WHEN (coalesce(o2.value,o1.value) / (EXTRACT(epoch FROM (o2.charttime - o1.charttime))/3600) < 22.5 AND EXTRACT(epoch FROM (o2.charttime - o1.charttime))/3600 >=2) THEN \
               TRUE \
               END as result \
               FROM urine o1\
               LEFT JOIN urine o2 \
               ON \
               o1.icustay_id = o2.icustay_id \
               AND o1.position = o2.position -1 \
              AND o1.charttime <> o2.charttime) \
               SELECT distinct on (icustay_id) icustay_id FROM tmp WHERE result IS TRUE'))
# Out:
#     icustay_id  position  position           charttime           charttime  \
# 0       200019         5         6 2178-07-08 18:00:00 2178-07-08 20:00:00
# 1       200019        30        31 2178-07-10 04:00:00 2178-07-10 06:00:00
# 2       200019        31        32 2178-07-10 06:00:00 2178-07-10 09:00:00
# 3       200019        35        36 2178-07-10 12:00:00 2178-07-10 14:00:00
# 4       200019        40        41 2178-07-10 18:00:00 2178-07-10 20:00:00
# 5       200019        41        42 2178-07-10 20:00:00 2178-07-10 23:00:00
# 6       200019        42        43 2178-07-10 23:00:00 2178-07-11 02:00:00
# 7       200019        43        44 2178-07-11 02:00:00 2178-07-11 05:00:00
# 8       200039         2         3 2121-12-26 08:00:00 2121-12-26 10:00:00
# 9       200039         6         7 2121-12-26 18:00:00 2121-12-26 20:00:00
# 10      200045        39        40 2116-07-12 09:00:00 2116-07-12 11:00:00
# 11      200045       431       432 2116-07-29 12:00:00 2116-07-29 14:00:00
# 12      200045       443       444 2116-07-30 08:00:00 2116-07-30 10:00:00
# 13      200059        46        47 2198-02-12 08:00:00 2198-02-12 10:00:00
# 14      200059        49        50 2198-02-12 12:00:00 2198-02-12 14:00:00
# 15      200059        66        67 2198-02-13 08:00:00 2198-02-13 10:00:00
# 16      200059        67        68 2198-02-13 10:00:00 2198-02-13 12:00:00
# 17      200059        68        69 2198-02-13 12:00:00 2198-02-13 16:00:00
# 18      200059        87        88 2198-02-14 12:00:00 2198-02-14 14:00:00
# 19      200059        99       100 2198-02-15 04:00:00 2198-02-15 06:00:00
# 20      200059       100       101 2198-02-15 06:00:00 2198-02-15 08:00:00
# 21      200059       209       210 2198-02-21 06:00:00 2198-02-21 08:00:00
# 22      200065         8         9 2120-03-23 06:00:00 2120-03-23 08:00:00
# 23      200065         9        10 2120-03-23 08:00:00 2120-03-23 10:00:00
# 24      200065        10        11 2120-03-23 10:00:00 2120-03-23 12:00:00
# 25      200065        12        13 2120-03-23 13:00:00 2120-03-23 15:00:00
# 26      200065        14        15 2120-03-23 16:00:00 2120-03-23 18:00:00
# 27      200065        15        16 2120-03-23 18:00:00 2120-03-23 20:00:00
# 28      200065        32        33 2120-03-24 12:00:00 2120-03-24 14:00:00
# 29      200065        34        35 2120-03-24 15:00:00 2120-03-24 20:00:00
# ..         ...       ...       ...                 ...                 ...
# 70      200065       106       107 2120-03-31 01:00:00 2120-03-31 03:00:00
# 71      200065       116       117 2120-03-31 12:00:00 2120-03-31 14:30:00
# 72      200065       121       122 2120-03-31 18:00:00 2120-03-31 20:00:00
# 73      200065       140       141 2120-04-01 16:00:00 2120-04-01 20:00:00
# 74      200065       141       142 2120-04-01 20:00:00 2120-04-01 22:00:00
# 75      200066         1         2 2188-10-07 01:00:00 2188-10-07 03:00:00
# 76      200066         7         8 2188-10-07 10:00:00 2188-10-08 00:00:00
# 77      200068        21        22 2193-10-06 12:00:00 2193-10-06 14:00:00
# 78      200071         9        10 2101-04-08 06:00:00 2101-04-08 08:00:00
# 79      200077        19        20 2163-04-09 16:00:00 2163-04-09 18:00:00
# 80      200077        32        33 2163-04-10 06:00:00 2163-04-10 08:00:00
# 81      200077        33        34 2163-04-10 08:00:00 2163-04-10 10:00:00
# 82      200077        38        39 2163-04-10 14:00:00 2163-04-10 16:00:00
# 83      200077        39        40 2163-04-10 16:00:00 2163-04-10 18:00:00
# 84      200077        40        41 2163-04-10 18:00:00 2163-04-10 20:00:00
# 85      200077        41        42 2163-04-10 20:00:00 2163-04-10 22:00:00
# 86      200077        42        43 2163-04-10 22:00:00 2163-04-11 00:00:00
# 87      200077        43        44 2163-04-11 00:00:00 2163-04-11 02:00:00
# 88      200077        44        45 2163-04-11 02:00:00 2163-04-11 04:00:00
# 89      200077        45        46 2163-04-11 04:00:00 2163-04-11 06:00:00
# 90      200077        46        47 2163-04-11 06:00:00 2163-04-11 08:00:00
# 91      200077        47        48 2163-04-11 08:00:00 2163-04-11 11:00:00
# 92      200077        48        49 2163-04-11 11:00:00 2163-04-11 13:00:00
# 93      200077        49        50 2163-04-11 13:00:00 2163-04-11 15:00:00
# 94      200077        52        53 2163-04-11 17:00:00 2163-04-11 20:00:00
# 95      200077        53        54 2163-04-11 20:00:00 2163-04-12 00:00:00
# 96      200077        54        55 2163-04-12 00:00:00 2163-04-12 04:00:00
# 97      200077        55        56 2163-04-12 04:00:00 2163-04-12 06:00:00
# 98      200077        56        57 2163-04-12 06:00:00 2163-04-12 08:00:00
# 99      200077        57        58 2163-04-12 08:00:00 2163-04-12 11:00:00
#
#     duree   val  vol_per_hour  result
# 0     2.0  20.0     10.000000    True
# 1     2.0  30.0     15.000000    True
# 2     3.0  40.0     13.333333    True
# 3     2.0  30.0     15.000000    True
# 4     2.0   0.0      0.000000    True
# 5     3.0   0.0      0.000000    True
# 6     3.0   0.0      0.000000    True
# 7     3.0   0.0      0.000000    True
# 8     2.0  35.0     17.500000    True
# 9     2.0  25.0     12.500000    True
# 10    2.0  40.0     20.000000    True
# 11    2.0  30.0     15.000000    True
# 12    2.0  40.0     20.000000    True
# 13    2.0  11.0      5.500000    True
# 14    2.0  22.0     11.000000    True
# 15    2.0  40.0     20.000000    True
# 16    2.0  30.0     15.000000    True
# 17    4.0  25.0      6.250000    True
# 18    2.0  25.0     12.500000    True
# 19    2.0  40.0     20.000000    True
# 20    2.0  40.0     20.000000    True
# 21    2.0  10.0      5.000000    True
# 22    2.0  10.0      5.000000    True
# 23    2.0  10.0      5.000000    True
# 24    2.0  10.0      5.000000    True
# 25    2.0   6.0      3.000000    True
# 26    2.0  10.0      5.000000    True
# 27    2.0  15.0      7.500000    True
# 28    2.0   0.0      0.000000    True
# 29    5.0  10.0      2.000000    True
# ..    ...   ...           ...     ...
# 70    2.0  25.0     12.500000    True
# 71    2.5  20.0      8.000000    True
# 72    2.0  30.0     15.000000    True
# 73    4.0  20.0      5.000000    True
# 74    2.0  40.0     20.000000    True
# 75    2.0  30.0     15.000000    True
# 76   14.0  50.0      3.571429    True
# 77    2.0  35.0     17.500000    True
# 78    2.0  40.0     20.000000    True
# 79    2.0  35.0     17.500000    True
# 80    2.0  15.0      7.500000    True
# 81    2.0  12.0      6.000000    True
# 82    2.0  20.0     10.000000    True
# 83    2.0  20.0     10.000000    True
# 84    2.0  23.0     11.500000    True
# 85    2.0  12.0      6.000000    True
# 86    2.0  10.0      5.000000    True
# 87    2.0  14.0      7.000000    True
# 88    2.0   7.0      3.500000    True
# 89    2.0   7.0      3.500000    True
# 90    2.0   7.0      3.500000    True
# 91    3.0   7.0      2.333333    True
# 92    2.0  14.0      7.000000    True
# 93    2.0   8.0      4.000000    True
# 94    3.0   2.0      0.666667    True
# 95    4.0  10.0      2.500000    True
# 96    4.0  10.0      2.500000    True
# 97    2.0   0.0      0.000000    True
# 98    2.0  23.0     11.500000    True
# 99    3.0  15.0      5.000000    True
#
# [100 rows x 9 columns]

# %%
print(get_data(f'SELECT max(valuenum), avg(valuenum),  count(1), itemid, valueuom, label \
FROM mimiciii.chartevents \
JOIN mimiciii.d_items USING (itemid) \
WHERE valuenum IS NOT NULL AND itemid IN (225678, 227457, 828, 3789, 6256) \
GROUP BY valueuom, itemid, label order by count DESC;'))
# Out:
#         max         avg   count  itemid valueuom                label
# 0    2292.0  218.370891  188850     828     None            Platelets
# 1  999999.0  224.696646  137351  227457     K/uL       Platelet Count
# 2    1147.0  282.603895   10449    3789     None  Platelet  (150-440)
# 3     533.0  180.966990     103  227457     None       Platelet Count

# %%
print(get_data(f'SELECT max(valuenum), avg(valuenum),  count(1), itemid, valueuom, label \
FROM mimiciii.chartevents \
JOIN mimiciii.d_items USING (itemid) \
WHERE valuenum IS NOT NULL AND valuenum < 155 AND  itemid IN (818, 1531, 225668) \
GROUP BY valueuom, itemid, label order by count DESC;'))
# Out:
#      max        avg  count  itemid valueuom                 label
# 0  153.0   2.847933  73025     818     None  Lactic Acid(0.5-2.0)
# 1   32.0   2.505627  69381  225668   mmol/L           Lactic Acid
# 2  153.0   2.778967  63233    1531     None           Lactic Acid
# 3  150.0  36.469767     43  225668     None           Lactic Acid

# %%
print(get_data("SELECT max(value), avg(value), median(value::numeric), count(1), itemid, label \
        FROM mimiciii.outputevents cd\
        JOIN mimiciii.d_items USING (itemid) \
        WHERE\
        label ~* 'urin'\
        AND  value != 0\
        GROUP BY valueuom, itemid, label order by count DESC;" ))
# Out:
#           max          avg                  median    count  itemid  \
# 0    11000.00   120.452865     80.0000000000000000  1879287   40055
# 1     2220.00    21.267898     18.0000000000000000   103610   43175
# 2     3775.00   291.912651    250.0000000000000000    62032   40069
# 3     3400.00   273.367249    200.0000000000000000     8354   40094
# 4     1600.00   120.367487     80.0000000000000000     6705   40715
# 5     8300.00   681.527274    405.0000000000000000     5848  226627
# 6     2000.00   131.609542    100.0000000000000000     4674   40473
# 7    19990.00   909.020668    750.0000000000000000     4161   40065
# 8     8000.00   599.445980    330.0000000000000000     3993   40061
# 9    28000.00  1872.169801   1600.0000000000000000     3116  227489
# 10    1350.00   137.628167    100.0000000000000000     2684   40057
# 11     850.00   109.790960     75.0000000000000000     2655   40056
# 12    4000.00   155.555754    100.0000000000000000     1677   40405
# 13    8240.00   790.958333    483.0000000000000000      624   40288
# 14    1550.00   189.309437     80.0000000000000000      551   40428
# 15    6490.00   728.579381    490.0000000000000000      485  226631
# 16     620.00   103.612091     80.0000000000000000      397   40096
# 17       7.50     3.432741      3.5000000000000000      270   43171
# 18     900.00   195.213178    150.0000000000000000      258   40085
# 19       9.00     3.649485      3.6500000954000000       97   43373
# 20     250.00    54.456790     40.0000000000000000       81   40651
# 21    1450.00   466.052632    325.0000000000000000       38   45927
# 22       5.70     3.785143      3.7000000477000000       35   43431
# 23     600.00   198.461538    150.0000000000000000       26   42507
# 24       7.20     2.501250      2.3500000238500000       24   43522
# 25    1300.00   453.846154    120.0000000000000000       13   42001
# 26       4.00     2.668750      2.8000000715500000        8   43589
# 27       6.10     3.080000      2.5999999046000000        5   43654
# 28     750.00   525.000000    550.0000000000000000        4   42810
# 29       4.60     3.475000      3.5500000715500000        4   43537
# ..        ...          ...                     ...      ...     ...
# 73       3.40     3.400000      3.4000000954000000        1   43333
# 74     500.00   500.000000    500.0000000000000000        1   41857
# 75     850.00   850.000000    850.0000000000000000        1   42765
# 76     900.00   900.000000    900.0000000000000000        1   46658
# 77       2.76     2.760000      2.7599999905000000        1   43576
# 78    1440.00  1440.000000   1440.0000000000000000        1   44481
# 79     900.00   900.000000    900.0000000000000000        1   46748
# 80    1300.00  1300.000000   1300.0000000000000000        1   46532
# 81     696.00   696.000000    696.0000000000000000        1   42592
# 82    5575.00  5575.000000   5575.0000000000000000        1   42068
# 83       1.80     1.800000  1.79999995230000000000        1   43638
# 84     500.00   500.000000    500.0000000000000000        1   42510
# 85     900.00   900.000000    900.0000000000000000        1   42130
# 86     498.00   498.000000    498.0000000000000000        1   43931
# 87     425.00   425.000000    425.0000000000000000        1   44103
# 88       3.50     3.500000      3.5000000000000000        1   43856
# 89     700.00   700.000000    700.0000000000000000        1   44278
# 90    1400.00  1400.000000   1400.0000000000000000        1   44837
# 91     700.00   700.000000    700.0000000000000000        1   44325
# 92     144.00   144.000000    144.0000000000000000        1   44911
# 93    2000.00  2000.000000   2000.0000000000000000        1   43897
# 94       4.80     4.800000      4.8000001907000000        1   43347
# 95       5.50     5.500000      5.5000000000000000        1   43633
# 96    1570.00  1570.000000   1570.0000000000000000        1   45804
# 97     500.00   500.000000    500.0000000000000000        1   44080
# 98     280.00   280.000000    280.0000000000000000        1   43093
# 99     692.00   692.000000    692.0000000000000000        1   46804
# 100    600.00   600.000000    600.0000000000000000        1   42666
# 101    800.00   800.000000    800.0000000000000000        1   42111
# 102      5.80     5.800000      5.8000001907000000        1   43372
#
#                             label
# 0                 Urine Out Foley
# 1                         Urine .
# 2                  Urine Out Void
# 3           Urine Out Condom Cath
# 4            Urine Out Suprapubic
# 5                        OR Urine
# 6           Urine Out IleoConduit
# 7               OR Out PACU Urine
# 8                 OR Out OR Urine
# 9    GU Irrigant/Urine Volume Out
# 10       Urine Out Rt Nephrostomy
# 11       Urine Out Lt Nephrostomy
# 12                Urine Out Other
# 13            PACU Out PACU Urine
# 14        Urine Out Straight Cath
# 15                     PACU Urine
# 16    Urine Out Ureteral Stent #1
# 17                 URINE CC/KG/HR
# 18          Urine Out Incontinent
# 19                 urine cc/kg/hr
# 20    Urine Out Ureteral Stent #2
# 21                     True Urine
# 22                  Urine cc/k/hr
# 23                     TRUE URINE
# 24                 Urine cc/kg/hr
# 25                       ER URINE
# 26                  urine cc/k/hr
# 27             urine o/p cc/kg/hr
# 28                angio urine out
# 29                      urine o/p
# ..                            ...
# 73                urine cc's/k/hr
# 74                urine out in er
# 75               FARR 6 URINE OUT
# 76                ED Urine output
# 77            24hr Urine cc/kg/hr
# 78                ER URINR OUTPUT
# 79             Cath Lab Urine Out
# 80                    Floor urine
# 81                 VICU URINE OUT
# 82             angio Urine output
# 83           urine output cc/k/hr
# 84              Urine in cath lab
# 85                ANGIO URINE O/P
# 86                Floor urine out
# 87                   ER urine out
# 88                 urine cc/k/ghr
# 89                       ER urine
# 90                       ED URINE
# 91                ED URINE OUTPUT
# 92           urine output farr-10
# 93                   urine in er.
# 94                    urine cc/kg
# 95                Urine,cc/kg/day
# 96              URINE OUTPUT-E.D.
# 97                       EW Urine
# 98                       URINE ED
# 99                  Farr  5 urine
# 100                E.R. URINE OUT
# 101             ANGIO FOLEY URINE
# 102             24hr urine output
#
# [103 rows x 6 columns]

# %%
print(get_data("SELECT * FROM mimiciii.d_items WHERE label ~* 'urin'"))
# Out:
#      row_id  itemid                                              label  \
# 0      1162     941                                      urine culture
# 1      1182    1011                                   urine osmolarity
# 2      1671    4855                                      Urine culture
# 3      1361    1352                                           urine pH
# 4       656     706                                      Urine [Color]
# 5       657     707                                       Urine Source
# 6       816    3140                                          Urine Cl-
# 7      3251    1880                                           Urine pH
# 8      3273    1917                                          Urine Na+
# 9      3274    1918                                          Urine Osm
# 10     3275    1919                                        Urine creat
# 11     2446    6035                                    Urinalysis sent
# 12     1913    5810                                      urine calcium
# 13     1914    5811                                   urine creatinine
# 14     1915    5812                                        Urine lytes
# 15     1994    5898                                           urine na
# 16     2910    3816                                      Urine Glucose
# 17     2911    3817                                         Urine Heme
# 18     2912    3818                                      Urine Ketones
# 19     2913    3819                                   Urine Leukocytes
# 20     2914    3822                                      Urine Protein
# 21     2950    1495                                           urine ph
# 22     3443    2224                                        URINE CREAT
# 23     3444    2225                                           URINE NA
# 24     3445    2226                                         URINE OSMO
# 25     3721    2688                                          URINE CL.
# 26     3722    2690                                          URINE OSM
# 27     3723    2691                                    URINE POTASSIUM
# 28     3724    2692                                       URINE SODIUM
# 29     2600    6204                                      urine for CMV
# ..      ...     ...                                                ...
# 144   13035  224016                                        Urine Color
# 145   14704  227027           Non-Operative Genitourinary (GENITOURIN)
# 146   14719  227042          Post-Operative Genitourinary (GENITOURIN)
# 147   14843  227489                       GU Irrigant/Urine Volume Out
# 148   14849  227519                              Urine output_ApacheIV
# 149   14832  227471                           Specific Gravity (urine)
# 150   12323   70077                                              URINE
# 151   12324   70078                            URINE,PROSTATIC MASSAGE
# 152   12325   70079                                              URINE
# 153   12326   70080                                       URINE,KIDNEY
# 154   12327   70081                                              URINE
# 155   12328   70082                          URINE,SUPRAPUBIC ASPIRATE
# 156   13456  224858                Patient Behavior During Application
# 157   15112  228028  I was present during the above procedure and a...
# 158   15123  228040  I was present during the above procedure and a...
# 159   12710  220799                          ZSpecific Gravity (urine)
# 160   15154  227956                                      Urinal/Bedpan
# 161   13550  224876                                   Urine Appearance
# 162   14420  226566                          Urine and GU Irrigant Out
# 163   15290  228095  I was present during the above procedure and a...
# 164   15317  228124  I was present during the above procedure and a...
# 165   12147   45415                                       ED Urine OUT
# 166   14485  226627                                           OR Urine
# 167   14489  226631                                         PACU Urine
# 168   15248  228050  I was present during the above procedure and a...
# 169   15261  228064  I was present during the above procedure and a...
# 170   15268  228071  I was present during the above procedure and a...
# 171   15275  228079  I was present during the above procedure and a...
# 172   15281  228086  I was present during the above procedure and a...
# 173   13671  225290  Present during key moments and agree with chec...
#
#                                           abbreviation    dbsource  \
# 0                                                 None     carevue
# 1                                                 None     carevue
# 2                                                 None     carevue
# 3                                                 None     carevue
# 4                                                 None     carevue
# 5                                                 None     carevue
# 6                                                 None     carevue
# 7                                                 None     carevue
# 8                                                 None     carevue
# 9                                                 None     carevue
# 10                                                None     carevue
# 11                                                None     carevue
# 12                                                None     carevue
# 13                                                None     carevue
# 14                                                None     carevue
# 15                                                None     carevue
# 16                                                None     carevue
# 17                                                None     carevue
# 18                                                None     carevue
# 19                                                None     carevue
# 20                                                None     carevue
# 21                                                None     carevue
# 22                                                None     carevue
# 23                                                None     carevue
# 24                                                None     carevue
# 25                                                None     carevue
# 26                                                None     carevue
# 27                                                None     carevue
# 28                                                None     carevue
# 29                                                None     carevue
# ..                                                 ...         ...
# 144                                        Urine Color  metavision
# 145                        Genitourinary Non-Operative  metavision
# 146                       Genitourinary Post-Operative  metavision
# 147                       GU Irrigant/Urine Volume Out  metavision
# 148                                       Urine output  metavision
# 149                           Specific Gravity (urine)  metavision
# 150                                               None    hospital
# 151                                               None    hospital
# 152                                               None    hospital
# 153                                               None    hospital
# 154                                               None    hospital
# 155                                               None    hospital
# 156           Pt. Behavior w/ Application (Behavioral)  metavision
# 157        I was present during the procedure (A-Line)  metavision
# 158     I was present during the above procedure (CVL)  metavision
# 159                          ZSpecific gravity (urine)  metavision
# 160                                      Urinal/Bedpan  metavision
# 161                                   Urine Appearance  metavision
# 162                          Urine and GU Irrigant Out  metavision
# 163   I was present during the above procedure (THCEN)  metavision
# 164              I was present for procedure (PA Line)  metavision
# 165                                               None     carevue
# 166                                           OR Urine  metavision
# 167                                         PACU Urine  metavision
# 168          I was present during the procedure (PICC)  metavision
# 169  I was present during the above procedure (Bronch)  metavision
# 170    I was present during the procedure (Intubation)  metavision
# 171      I was present during the above procedure (LP)  metavision
# 172   I was present during the above procedure (PACEN)  metavision
# 173  Present during procedure/agree w/ checklist (P...  metavision
#
#                 linksto                   category unitname        param_type  \
# 0           chartevents                       None     None              None
# 1           chartevents                       None     None              None
# 2           chartevents                       None     None              None
# 3           chartevents                       None     None              None
# 4           chartevents                       None     None              None
# 5           chartevents                       None     None              None
# 6           chartevents                       None     None              None
# 7           chartevents                       None     None              None
# 8           chartevents                       None     None              None
# 9           chartevents                       None     None              None
# 10          chartevents                       None     None              None
# 11          chartevents                       None     None              None
# 12          chartevents                       None     None              None
# 13          chartevents                       None     None              None
# 14          chartevents                       None     None              None
# 15          chartevents                       None     None              None
# 16          chartevents                      Urine     None              None
# 17          chartevents                      Urine     None              None
# 18          chartevents                      Urine     None              None
# 19          chartevents                      Urine     None              None
# 20          chartevents                      Urine     None              None
# 21          chartevents                       None     None              None
# 22          chartevents                       None     None              None
# 23          chartevents                       None     None              None
# 24          chartevents                       None     None              None
# 25          chartevents                       None     None              None
# 26          chartevents                       None     None              None
# 27          chartevents                       None     None              None
# 28          chartevents                       None     None              None
# 29          chartevents                       None     None              None
# ..                  ...                        ...      ...               ...
# 144         chartevents                      GI/GU     None              Text
# 145         chartevents         Scores - APACHE IV     None              Text
# 146         chartevents         Scores - APACHE IV     None              Text
# 147        outputevents                     Output       mL           Numeric
# 148         chartevents     Scores - APACHE IV (2)     None           Numeric
# 149         chartevents                       Labs     None  Numeric with tag
# 150  microbiologyevents                   SPECIMEN     None              None
# 151  microbiologyevents                   SPECIMEN     None              None
# 152  microbiologyevents                   SPECIMEN     None              None
# 153  microbiologyevents                   SPECIMEN     None              None
# 154  microbiologyevents                   SPECIMEN     None              None
# 155  microbiologyevents                   SPECIMEN     None              None
# 156         chartevents  Restraint/Support Systems     None              Text
# 157         chartevents    Arterial Line Insertion     None          Checkbox
# 158         chartevents              CVL Insertion     None          Checkbox
# 159         chartevents                       Labs     None           Numeric
# 160         chartevents  Restraint/Support Systems     None              Text
# 161         chartevents                      GI/GU     None              Text
# 162        outputevents                     Output       mL           Numeric
# 163         chartevents              Thoracentesis     None          Checkbox
# 164         chartevents          PA Line Insertion     None          Checkbox
# 165        outputevents                       None     None              None
# 166        outputevents                     Output       mL           Numeric
# 167        outputevents                     Output       mL           Numeric
# 168         chartevents        PICC Line Insertion     None          Checkbox
# 169         chartevents               Bronchoscopy     None          Checkbox
# 170         chartevents                 Intubation     None          Checkbox
# 171         chartevents            Lumbar Puncture     None          Checkbox
# 172         chartevents               Paracentesis     None          Checkbox
# 173         chartevents        PICC Line Insertion     None          Checkbox
#
#     conceptid
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
# 20       None
# 21       None
# 22       None
# 23       None
# 24       None
# 25       None
# 26       None
# 27       None
# 28       None
# 29       None
# ..        ...
# 144      None
# 145      None
# 146      None
# 147      None
# 148      None
# 149      None
# 150      None
# 151      None
# 152      None
# 153      None
# 154      None
# 155      None
# 156      None
# 157      None
# 158      None
# 159      None
# 160      None
# 161      None
# 162      None
# 163      None
# 164      None
# 165      None
# 166      None
# 167      None
# 168      None
# 169      None
# 170      None
# 171      None
# 172      None
# 173      None
#
# [174 rows x 10 columns]

# %%
ci=cardiac_index[cardiac_index['valid'] == True]
mp=mean_pressure[mean_pressure['valid'] == True]
sp=systol_pressure[systol_pressure['valid'] == True]
th=thromb[thromb['valid'] == True]
vs=venus_sat[venus_sat['valid'] == True]

# %%
print(get_data('SELECT count(1)  FROM sepsis.angus2013_sepsis_severe WHERE hadm_id NOT IN (SELECT hadm_id FROM sepsis.angus2013_sepsis)'))
# Out:
#    count
# 0      0

# %%
#TEST IF JEROME CODES ARE OK
import re
f = open('infect_icd9_jab.txt')
inf = f.read()
inf = list(filter(len,re.split("\s+|\n", inf)))
inf = [x for x in inf if len(x) != 3]
#inf = list(filter(len,re.split("\s+|\n", inf)))
pred = "'),('".join(inf)
#get_data(f"WITH inf as (SELECT column1 as cd FROM (VALUES ('{pred}')) as tmp)\
#         SELECT count(1) FROM inf WHERE cd NOT IN (SELECT icd9_code FROM mimiciii.diagnoses_icd) ")
get_data(f"WITH inf as (SELECT column1 as cd FROM (VALUES ('{pred}')) as tmp)\
           SELECT count(distinct hadm_id) \
           FROM mimiciii.diagnoses_icd \
           WHERE icd9_code IN (SELECT * FROM inf)")
pred = "','".join(list(set(inf)))
a =(f"SELECT DISTINCT subject_id, hadm_id \
FROM mimiciii.diagnoses_icd \
WHERE icd9_code IN ('{pred}')")
f1=open('jero_icd9.sql', 'w+')
f1.write(a)
# Out:
# 17072

# %%
import pylab as plt
from matplotlib_venn import venn3
# ACCP: dans infection icd9
# 2 critères dans chap general et inflamatory
# 1 dans Soit organ disf SOIT tissue hypo SOIT émodynamique variable
accp_sql = get_data('WITH crit1 AS (SELECT hadm_id FROM sepsis.ch0_infection_pop), \
tmp AS (SELECT count(1), hadm_id FROM ( SELECT hadm_id FROM sepsis.ch1_general_vars_temp UNION ALL  SELECT hadm_id FROM sepsis.ch1_general_vars_hr UNION ALL SELECT hadm_id FROM sepsis.ch1_general_vars_rr UNION ALL  SELECT hadm_id FROM sepsis.ch1_general_vars_glasgow UNION ALL  SELECT hadm_id FROM sepsis.ch1_general_vars_gly UNION ALL  SELECT hadm_id FROM sepsis.ch1_general_vars_fluid ) as tmp GROUP BY hadm_id) ,\
crit2 as (SELECT hadm_id FROM tmp WHERE count >= 2), \
crit3 as (SELECT hadm_id FROM (SELECT hadm_id FROM sepsis.ch4_organ_dysf_art_hypox UNION ALL SELECT hadm_id FROM sepsis.ch4_organ_dysf_creat UNION ALL SELECT hadm_id FROM sepsis.ch4_organ_dysf_thromb UNION ALL SELECT hadm_id FROM sepsis.ch4_organ_dysf_plat UNION ALL SELECT hadm_id FROM sepsis.ch4_organ_dysf_urin UNION ALL SELECT hadm_id FROM sepsis.ch5_tissue_perf) as tmp2) \
SELECT DISTINCT hadm_id FROM (SELECT * FROM crit1 INTERSECT SELECT * FROM crit2 INTERSECT SELECT * FROM crit3) as tmp3 \
                    ')
#Sepsis3: dans infection icd9
# sofa >= 2 
# lactate <2 ou abs
sepsis_severe_sql = get_data('SELECT distinct hadm_id FROM angus2013_sepsis_severe')
#BCSC: only codes
# +  le meme jour toutes ces choses là:
# prélevement
# bacterio
# remplissage
sepsis_shock_sql = get_data('SELECT distinct hadm_id FROM angus2013_sepsis_severe' )
set1 = set(accp_sql['hadm_id'])
#idx = df['sepsis_angus']==1 
set2 = set(sepsis_severe_sql['hadm_id']) 
#idx = df['sofa']>=2 
set3 = set(sepsis_shock_sql['hadm_id'])
set3=set2

# %%
plt.figure(figsize=[16,16])
plt.rcParams.update({'font.size': 14})
venn3([set1, set2, set3], ('ACCP', 'Sepsis3', 'BCSC'),      
subset_label_formatter=lambda x: '{:,}\n{:2.1f}%'.format(x, x*100.0/50000))
plt.savefig('sepsis3-venn.png')
plt.show()
